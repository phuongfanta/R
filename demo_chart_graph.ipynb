# %%
data <- read.csv("https://raw.githubusercontent.com/phuongfanta/R/master/baseball.csv")
head(data)
# Out:
#   X height weight
# 1 0 1.8796 81.64656
# 2 1 1.8796 97.52228
# 3 2 1.8288 95.25432
# 4 3 1.8288 95.25432
# 5 4 1.8542 85.27530
# 6 5 1.7526 79.83219

# %%
boxplot(data$height, main="Height", ylab="(m)")
# Out:
# Plot with title “Height”

# %%
boxplot(data$height, data = data,     
    ylab = "m",   
    notch = TRUE,
    varwidth = TRUE, 
    col = c("green"),
    main = "Height"
)
# Out:
# Plot with title “Height”
